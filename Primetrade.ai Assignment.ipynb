# %%
#### Assessment Task: Fetching and Analyzing Top 50 Live Cryptocurrency Data


## Objective:
####The goal of this assessment is to fetch live cryptocurrency data for the top 50 cryptocurrencies, analyze it, and present the data in a live-updating Excel sheet. The Excel sheet should continuously update with the latest cryptocurrency prices.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# URL to fetch top 50 cryptocurrencies by market cap from CoinGecko API
url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {
    'vs_currency': 'usd',
    'order': 'market_cap_desc',
    'per_page': 50,
    'page': 1
}

response = requests.get(url, params=params)
data = response.json()

# %%
# Creating a DataFrame to store the relevant data
cryptos = []
for coin in data:
    cryptos.append({
        'Name': coin['name'],
        'Symbol': coin['symbol'],
        'Current Price (USD)': coin['current_price'],
        'Market Cap (USD)': coin['market_cap'],
        '24h Trading Volume (USD)': coin['total_volume'],
        '24h Price Change (%)': coin['price_change_percentage_24h']
    })

df = pd.DataFrame(cryptos)
print(df)
# Out:
#                                      Name  Symbol  Current Price (USD)  \
# 0                                 Bitcoin     btc         97076.000000
# 1                                Ethereum     eth          3145.690000
# 2                                  Tether    usdt             1.001000
# 3                                  Solana     sol           242.670000
# 4                                     BNB     bnb           613.780000
# 5                                     XRP     xrp             1.120000
# 6                                Dogecoin    doge             0.386148
# 7                                    USDC    usdc             1.000000
# 8                       Lido Staked Ether   steth          3145.840000
# 9                                 Cardano     ada             0.782540
# 10                                   TRON     trx             0.198929
# 11                              Shiba Inu    shib             0.000024
# 12                                Toncoin     ton             5.550000
# 13                        Wrapped Bitcoin    wbtc         96727.000000
# 14                              Avalanche    avax            34.270000
# 15                          Wrapped stETH  wsteth          3717.790000
# 16                           Bitcoin Cash     bch           520.070000
# 17                                    Sui     sui             3.560000
# 18                              Chainlink    link            14.670000
# 19                                   WETH    weth          3145.450000
# 20                               Polkadot     dot             5.700000
# 21                                   Pepe    pepe             0.000019
# 22                              LEO Token     leo             8.520000
# 23                                Stellar     xlm             0.239649
# 24                               Litecoin     ltc            90.110000
# 25                          NEAR Protocol    near             5.510000
# 26                                  Aptos     apt            11.680000
# 27                           Wrapped eETH   weeth          3311.490000
# 28                                Uniswap     uni             8.860000
# 29                                   USDS    usds             0.997383
# 30                                 Cronos     cro             0.176354
# 31                                 Hedera    hbar             0.124293
# 32                      Internet Computer     icp             9.060000
# 33                       Ethereum Classic     etc            26.780000
# 34                                   Bonk    bonk             0.000052
# 35                                  Kaspa     kas             0.153159
# 36                                 Render  render             7.380000
# 37                            Ethena USDe    usde             1.002000
# 38                              Bittensor     tao           480.730000
# 39                         POL (ex-MATIC)     pol             0.439126
# 40                          WhiteBIT Coin     wbt            24.160000
# 41                                    Dai     dai             1.001000
# 42  Artificial Superintelligence Alliance     fet             1.240000
# 43                                 MANTRA      om             3.570000
# 44                              dogwifhat     wif             3.190000
# 45                                 Monero     xmr           160.470000
# 46                                 Stacks     stx             1.930000
# 47                               Arbitrum     arb             0.708336
# 48                               Filecoin     fil             4.500000
# 49                                    OKB     okb            44.360000
#
#     Market Cap (USD)  24h Trading Volume (USD)  24h Price Change (%)
# 0      1921052599365              104432515827               4.08092
# 1       378928954271               37186087239               0.63424
# 2       130346557909              103025092205               0.02140
# 3       115182077870                9755750835               1.92312
# 4        89559130997                1857391093              -0.17068
# 5        63896604437                7798903999               2.38478
# 6        56724215324               10346353644              -1.92084
# 7        37889361451                9693658999               0.03444
# 8        30795199940                 126862895               0.70353
# 9        28029058342                3716813789              -3.98101
# 10       17099691456                1006628168               0.28625
# 11       14211102210                1337850130              -1.90371
# 12       14167231583                 552631571               1.74338
# 13       14141286770                 691265397               3.98131
# 14       14019926723                 886468292              -1.54334
# 15       13479493212                  95218678               0.54185
# 16       10296581714                1637704800              17.49704
# 17       10140879252                1673910374              -5.85694
# 18        9196663114                1100214792               0.12916
# 19        9191742110                1062465684               0.74432
# 20        8213648739                 750238980              -4.58258
# 21        8160862334                5058563545              -4.90999
# 22        7879589989                   3456271               1.13504
# 23        7187996386                1648576173               2.85434
# 24        6779987805                1256280872               4.61968
# 25        6716392252                 704688388              -3.26944
# 26        6227082467                1337699295              -6.27763
# 27        5713564886                  19705595               0.63248
# 28        5321562380                 455205304              -3.33997
# 29        5242893347                   7928598              -0.29621
# 30        4787281925                  87944388              -2.13173
# 31        4684920295                1155221565               0.89072
# 32        4298029057                 244073628              -1.54607
# 33        4007701223                 504283941               3.50977
# 34        3901580348                2341324267              -6.83276
# 35        3856419527                 161093045              -4.44247
# 36        3822685206                 452078671              -9.22843
# 37        3583855282                 245139036              -0.06833
# 38        3551598545                 309607257               0.95119
# 39        3499276052                 433630813               1.36162
# 40        3480946874                  30841667               0.99459
# 41        3435260021                 138757946               0.18238
# 42        3229100407                 477863062              -4.63167
# 43        3215084189                 282300840             -10.30269
# 44        3186771875                1058492646              -4.57329
# 45        2965681528                  75318235               0.88601
# 46        2904538190                 328381433               4.52326
# 47        2902306263                 848623108               2.51059
# 48        2704049006                 530862549               2.45791
# 49        2662432377                   8604087               0.45867

# %% [markdown]
# ###### Step-2 Data Analysis

# %% [markdown]
# ##### Perform basic analysis on the live data fetched. Your analysis should include:
#
# - Identifying the top 5 cryptocurrencies by market cap.
# - Calculating the average price of the top 50 cryptocurrencies.
# - Analyzing the highest and lowest 24-hour percentage price change among the top 50.

# %%
# Top 5 cryptocurrencies by market cap
top_5 = df.nlargest(5, 'Market Cap (USD)')
print("Top 5 Cryptos by Market Cap:")
print(top_5)
# Out:
# Top 5 Cryptos by Market Cap:
#        Name Symbol  Current Price (USD)  Market Cap (USD)  \
# 0   Bitcoin    btc            97076.000     1921052599365
# 1  Ethereum    eth             3145.690      378928954271
# 2    Tether   usdt                1.001      130346557909
# 3    Solana    sol              242.670      115182077870
# 4       BNB    bnb              613.780       89559130997
#
#    24h Trading Volume (USD)  24h Price Change (%)
# 0              104432515827               4.08092
# 1               37186087239               0.63424
# 2              103025092205               0.02140
# 3                9755750835               1.92312
# 4                1857391093              -0.17068

# %%
# Average price of the top 50 cryptocurrencies
average_price = df['Current Price (USD)'].mean()
print(f"Average Price of Top 50 Cryptos: ${average_price:.2f}")
# Out:
# Average Price of Top 50 Cryptos: $4252.22

# %%
# Highest 24-hour price change
highest_change = df.loc[df['24h Price Change (%)'].idxmax()]
print("Highest 24h Price Change:")
print(highest_change)
# Out:
# Highest 24h Price Change:
# Name                        Bitcoin Cash
# Symbol                               bch
# Current Price (USD)               520.07
# Market Cap (USD)             10296581714
# 24h Trading Volume (USD)      1637704800
# 24h Price Change (%)            17.49704
# Name: 16, dtype: object

# %%
# lowest 24-hour price change
lowest_change = df.loc[df['24h Price Change (%)'].idxmin()]
print("Lowest 24h Price Change:")
print(lowest_change)
# Out:
# Lowest 24h Price Change:
# Name                            MANTRA
# Symbol                              om
# Current Price (USD)               3.57
# Market Cap (USD)            3215084189
# 24h Trading Volume (USD)     282300840
# 24h Price Change (%)         -10.30269
# Name: 43, dtype: object

# %% [markdown]
# #####  Step 3 -  Live-Running Excel Sheet
#
# - Set Up Live Updating in Excel:
# - fetch live data directly into Excel from the API.
# - Continuously update the data (e.g., every 5 minutes).
# - Show the live prices and other key metrics.

# %%
import pandas as pd
import requests
from openpyxl import load_workbook

# %%
# Define the URL and parameters again
url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {'vs_currency': 'usd', 'order': 'market_cap_desc', 'per_page': 50, 'page': 1}

def fetch_and_update():
    # Fetch the latest data
    response = requests.get(url, params=params)
    data = response.json()

    cryptos = []
    for coin in data:
        cryptos.append({
            'Name': coin['name'],
            'Symbol': coin['symbol'],
            'Current Price (USD)': coin['current_price'],
            'Market Cap (USD)': coin['market_cap'],
            '24h Trading Volume (USD)': coin['total_volume'],
            '24h Price Change (%)': coin['price_change_percentage_24h']
        })

    df = pd.DataFrame(cryptos)

# %%
df
# Out:
#                                      Name  Symbol  Current Price (USD)  \
# 0                                 Bitcoin     btc         97076.000000
# 1                                Ethereum     eth          3145.690000
# 2                                  Tether    usdt             1.001000
# 3                                  Solana     sol           242.670000
# 4                                     BNB     bnb           613.780000
# 5                                     XRP     xrp             1.120000
# 6                                Dogecoin    doge             0.386148
# 7                                    USDC    usdc             1.000000
# 8                       Lido Staked Ether   steth          3145.840000
# 9                                 Cardano     ada             0.782540
# 10                                   TRON     trx             0.198929
# 11                              Shiba Inu    shib             0.000024
# 12                                Toncoin     ton             5.550000
# 13                        Wrapped Bitcoin    wbtc         96727.000000
# 14                              Avalanche    avax            34.270000
# 15                          Wrapped stETH  wsteth          3717.790000
# 16                           Bitcoin Cash     bch           520.070000
# 17                                    Sui     sui             3.560000
# 18                              Chainlink    link            14.670000
# 19                                   WETH    weth          3145.450000
# 20                               Polkadot     dot             5.700000
# 21                                   Pepe    pepe             0.000019
# 22                              LEO Token     leo             8.520000
# 23                                Stellar     xlm             0.239649
# 24                               Litecoin     ltc            90.110000
# 25                          NEAR Protocol    near             5.510000
# 26                                  Aptos     apt            11.680000
# 27                           Wrapped eETH   weeth          3311.490000
# 28                                Uniswap     uni             8.860000
# 29                                   USDS    usds             0.997383
# 30                                 Cronos     cro             0.176354
# 31                                 Hedera    hbar             0.124293
# 32                      Internet Computer     icp             9.060000
# 33                       Ethereum Classic     etc            26.780000
# 34                                   Bonk    bonk             0.000052
# 35                                  Kaspa     kas             0.153159
# 36                                 Render  render             7.380000
# 37                            Ethena USDe    usde             1.002000
# 38                              Bittensor     tao           480.730000
# 39                         POL (ex-MATIC)     pol             0.439126
# 40                          WhiteBIT Coin     wbt            24.160000
# 41                                    Dai     dai             1.001000
# 42  Artificial Superintelligence Alliance     fet             1.240000
# 43                                 MANTRA      om             3.570000
# 44                              dogwifhat     wif             3.190000
# 45                                 Monero     xmr           160.470000
# 46                                 Stacks     stx             1.930000
# 47                               Arbitrum     arb             0.708336
# 48                               Filecoin     fil             4.500000
# 49                                    OKB     okb            44.360000
#
#     Market Cap (USD)  24h Trading Volume (USD)  24h Price Change (%)
# 0      1921052599365              104432515827               4.08092
# 1       378928954271               37186087239               0.63424
# 2       130346557909              103025092205               0.02140
# 3       115182077870                9755750835               1.92312
# 4        89559130997                1857391093              -0.17068
# 5        63896604437                7798903999               2.38478
# 6        56724215324               10346353644              -1.92084
# 7        37889361451                9693658999               0.03444
# 8        30795199940                 126862895               0.70353
# 9        28029058342                3716813789              -3.98101
# 10       17099691456                1006628168               0.28625
# 11       14211102210                1337850130              -1.90371
# 12       14167231583                 552631571               1.74338
# 13       14141286770                 691265397               3.98131
# 14       14019926723                 886468292              -1.54334
# 15       13479493212                  95218678               0.54185
# 16       10296581714                1637704800              17.49704
# 17       10140879252                1673910374              -5.85694
# 18        9196663114                1100214792               0.12916
# 19        9191742110                1062465684               0.74432
# 20        8213648739                 750238980              -4.58258
# 21        8160862334                5058563545              -4.90999
# 22        7879589989                   3456271               1.13504
# 23        7187996386                1648576173               2.85434
# 24        6779987805                1256280872               4.61968
# 25        6716392252                 704688388              -3.26944
# 26        6227082467                1337699295              -6.27763
# 27        5713564886                  19705595               0.63248
# 28        5321562380                 455205304              -3.33997
# 29        5242893347                   7928598              -0.29621
# 30        4787281925                  87944388              -2.13173
# 31        4684920295                1155221565               0.89072
# 32        4298029057                 244073628              -1.54607
# 33        4007701223                 504283941               3.50977
# 34        3901580348                2341324267              -6.83276
# 35        3856419527                 161093045              -4.44247
# 36        3822685206                 452078671              -9.22843
# 37        3583855282                 245139036              -0.06833
# 38        3551598545                 309607257               0.95119
# 39        3499276052                 433630813               1.36162
# 40        3480946874                  30841667               0.99459
# 41        3435260021                 138757946               0.18238
# 42        3229100407                 477863062              -4.63167
# 43        3215084189                 282300840             -10.30269
# 44        3186771875                1058492646              -4.57329
# 45        2965681528                  75318235               0.88601
# 46        2904538190                 328381433               4.52326
# 47        2902306263                 848623108               2.51059
# 48        2704049006                 530862549               2.45791
# 49        2662432377                   8604087               0.45867

# %%
 # Save data to Excel file
with pd.ExcelWriter('crypto_data.xlsx', engine='openpyxl', mode='w') as writer:
        df.to_excel(writer, sheet_name='Top 50 Cryptos', index=False)

# Call the function to fetch data and write to Excel
fetch_and_update()

# %%
df.to_excel('crypto_data.xlsx', engine='openpyxl', index=False)

# %%
import os
import subprocess

# Save the data to an Excel file
df.to_excel('crypto_data.xlsx', engine='openpyxl', index=False)

# Open the Excel file automatically based on the operating system
file_path = 'crypto_data.xlsx'

# For Windows
if os.name == 'nt':  
    subprocess.Popen(['start', file_path], shell=True)
    
# For macOS or Linux
else:  
    subprocess.Popen(['open', file_path])

# %%
import pandas as pd
import requests
import time
from openpyxl import load_workbook

# Define the URL and parameters for the API
url = 'https://api.coingecko.com/api/v3/coins/markets'
params = {'vs_currency': 'usd', 'order': 'market_cap_desc', 'per_page': 50, 'page': 1}

def fetch_and_update():
    # Fetch the latest data from CoinGecko API
    response = requests.get(url, params=params)
    data = response.json()

    cryptos = []
    for coin in data:
        cryptos.append({
            'Name': coin['name'],
            'Symbol': coin['symbol'],
            'Current Price (USD)': coin['current_price'],
            'Market Cap (USD)': coin['market_cap'],
            '24h Trading Volume (USD)': coin['total_volume'],
            '24h Price Change (%)': coin['price_change_percentage_24h']
        })

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(cryptos)

    # Save data to Excel file with the 'openpyxl' engine
    with pd.ExcelWriter('crypto_data.xlsx', engine='openpyxl', mode='w') as writer:
        df.to_excel(writer, sheet_name='Top 50 Cryptos', index=False)

    print("Data updated successfully.")

while True:
    fetch_and_update()
    time.sleep(300)
# Out:
# Data updated successfully.
# Data updated successfully.
# Data updated successfully.
# Data updated successfully.
# Data updated successfully.
